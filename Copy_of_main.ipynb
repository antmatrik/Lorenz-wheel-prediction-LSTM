# %%
# !git clone https://github.com/fdiskl/abfs26
# Out:
# Cloning into 'abfs26'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 297 (delta 28), reused 44 (delta 18), pack-reused 241 (from 2)
# Receiving objects: 100% (297/297), 96.39 MiB | 20.48 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd abfs26/second
# Out:
# [Errno 2] No such file or directory: 'abfs26/second'
# /content/abfs26/second/abfs26/second

# %%
# !pip install -r requirements.txt

# %%
# !python main.py
# Out:
# [PREDICT] file=test.csv, input_points=9000, output_points=1800
# Traceback (most recent call last):
#   File "/content/abfs26/second/abfs26/second/main.py", line 639, in <module>
#     main()
#   File "/content/abfs26/second/abfs26/second/main.py", line 633, in main
#     predict_mode()
#   File "/content/abfs26/second/abfs26/second/main.py", line 573, in predict_mode
#     raise FileNotFoundError(f"Weights file not found: {weights_path}")
# FileNotFoundError: Weights file not found: lstm_weights.weights.h5
